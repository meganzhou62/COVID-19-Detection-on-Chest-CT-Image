# %% [markdown]
# This notbeook is to collect the image data from Kaggle. Since the size of zipped data set is 31G, we will directly use Kaggle API to download the data and store it in Google drive. We will also need to unzip the dataset in Google drive and obtain our final data.
#
#
# Kaggle: https://www.kaggle.com/hgunraj/covidxct

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# Use Kaggle API to download image data to Google Drive

# %%
#Configuration environment
import os

os.environ['KAGGLE_USERNAME'] = "skyeczy" # username from the json file
os.environ['KAGGLE_KEY'] = "69bd62b67f259bdc16a56d9c423bf0fe" # key from the json file

# %%
# !kaggle datasets download -d hgunraj/covidxct
# Out:
# ...
# 100% 28.7G/28.7G [05:50<00:00, 121MB/s]
# 100% 28.7G/28.7G [05:50<00:00, 87.9MB/s]

# %%
ls /content
# Out:
# covidxct.zip  sample_data/

# %%
ls /gdrive/MyDrive/AML_group13/Code/
# Out:
# DataCollection.ipynb

# %%
import shutil

# %%
shutil.move("/content/covidxct.zip", "/gdrive/MyDrive/AML_group13/Code")
# Out:
# '/gdrive/MyDrive/AML_group13/Code/covidxct.zip'

# %% [markdown]
# Unzip dataset

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !mkdir /gdrive/MyDrive/AML_group13/Data

# %%
# !unzip /gdrive/MyDrive/AML_group13/Code/covidxct.zip -d /gdrive/MyDrive/AML_group13/Data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0028.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0035.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0037.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0042.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0043.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0382_ct-0045.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0383_0-0032.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0383_0-0033.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0383_1_ct-0018.png
#   inflating: /gdrive/MyDrive/AML_group13/Data/2A_images/volume-covid19-A-0383_1_ct-0019.png
# ...

# %%
# !mkdir /gdrive/MyDrive/AML/AML_group13/Data_resize

# %%
# !unzip /gdrive/MyDrive/AML/AML_group13/Code/resized_images.zip -d /gdrive/MyDrive/AML/AML_group13/Data_resize
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0088.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0089.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0090.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0091.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0092.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0093.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0094.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0095.png
#  extracting: /gdrive/MyDrive/AML/AML_group13/Data_resize/Data/2A_images/val/Normal_756_191_0096.png
# ...
